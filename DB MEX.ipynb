# %%
#Datos de DB The World Bank
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('Trafico_AereoMex.csv')
data
# Out:
#     Year  Abordajes
# 0   1995      37613
# 1   1996      41723
# 2   1997      42442
# 3   1998      46874
# 4   1999      47273
# 5   2000      48333
# 6   2001      46615
# 7   2002      51616
# 8   2003      54132
# 9   2004      54387
# 10  2005      54054
# 11  2006      66163
# 12  2007      77169
# 13  2008      74582
# 14  2009      69185
# 15  2010      78770
# 16  2011      79728
# 17  2012      79353
# 18  2013      77717
# 19  2014      80683
# 20  2015      83401
# 21  2016      84683
# 22  2017      86316
# 23  2018      87924
# 24  2019      89049

# %%
x=data['Year']
y=data['Abordajes']
plt.scatter(x,y,s=5)
plt.grid()
